# %% [markdown]
# # 01 Business Understanding

# %% [markdown]
# Objetivo CRISP-DM: modelar condiciones de sequía mensual para Chicoral usando variables climáticas y rezagos ENSO.

# %% [markdown]
# Unidad de análisis: observación mensual. Riesgos: cobertura irregular, faltantes y discontinuidades temporales.

# %% [markdown]
# Criterios de éxito: pipeline reproducible Bronze→Silver→Gold sin modificar datos fuente, evaluación cronológica contra baseline ingenuo.

# %%
from pathlib import Path
Path('reports/crisp_dm').mkdir(parents=True, exist_ok=True)
print('Repositorio listo para CRISP-DM')
