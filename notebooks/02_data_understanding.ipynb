# %% [markdown]
# # 02 Data Understanding

# %% [markdown]
# Este notebook carga salidas reproducibles de `src` y perfila cobertura, faltantes y advertencias de continuidad.

# %%
from src.data_ingestion import run_bronze_to_silver
from src.data_quality import run_silver_quality_checks
outputs = run_bronze_to_silver()
quality = run_silver_quality_checks()
quality['quality']

# %%
quality['continuity'].head()
