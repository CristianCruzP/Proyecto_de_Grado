# %% [markdown]
# # 03 Data Preparation

# %% [markdown]
# Orquesta Bronze→Silver→Gold usando funciones de `src`.

# %% [markdown]
# No se imputan faltantes silenciosamente; NaN se conservan y reportan.

# %%
from src.data_ingestion import run_bronze_to_silver
from src.data_quality import run_silver_quality_checks
from src.feature_engineering import build_gold_dataset
run_bronze_to_silver(); run_silver_quality_checks(); gold = build_gold_dataset(); gold.head()
